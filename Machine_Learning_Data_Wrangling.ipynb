# %% [markdown]
# <a href="https://colab.research.google.com/github/Am-CheaChamroeun/Machine-Learning-Data-Wrangling/blob/main/Machine_Learning_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn #machine learning
import numpy as np # Mathematic Computations
import pandas as pd #Data management

# %%
#1. Load the dataset
dataset = pd.read_csv("https://raw.githubusercontent.com/Am-CheaChamroeun/Machine-Learning-Data-Wrangling/main/airline_passenger_satisfaction.csv")
dataset.head(5)
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
#dimension : rows, columns
dataset.shape
# Out:
# (129880, 24)

# %%
#describe the dataset
dataset.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
#Check the variable(Numerical / categorical)
numerical_variable = dataset.columns[dataset.dtypes !=  'object']
dataset[numerical_variable].head(5)

categorical_variable = dataset.columns[dataset.dtypes ==  'object']
dataset[categorical_variable].head(5)
# Out:
#    Gender Customer Type Type of Travel     Class             Satisfaction
# 0    Male    First-time       Business  Business  Neutral or Dissatisfied
# 1  Female     Returning       Business  Business                Satisfied
# 2    Male     Returning       Business  Business                Satisfied
# 3    Male     Returning       Business  Business                Satisfied
# 4  Female     Returning       Business  Business                Satisfied

# %%
dataset[numerical_variable].head(5)
# Out:
#    ID  Age  Flight Distance  Departure Delay  Arrival Delay  \
# 0   1   48              821                2            5.0
# 1   2   35              821               26           39.0
# 2   3   41              853                0            0.0
# 3   4   50             1905                0            0.0
# 4   5   49             3470                0            1.0
#
#    Departure and Arrival Time Convenience  Ease of Online Booking  \
# 0                                       3                       3
# 1                                       2                       2
# 2                                       4                       4
# 3                                       2                       2
# 4                                       3                       3
#
#    Check-in Service  Online Boarding  Gate Location  On-board Service  \
# 0                 4                3              3                 3
# ...

# %%
dataset[categorical_variable].head(5)
# Out:
#    Gender Customer Type Type of Travel     Class             Satisfaction
# 0    Male    First-time       Business  Business  Neutral or Dissatisfied
# 1  Female     Returning       Business  Business                Satisfied
# 2    Male     Returning       Business  Business                Satisfied
# 3    Male     Returning       Business  Business                Satisfied
# 4  Female     Returning       Business  Business                Satisfied

# %%
#Missing values
dataset.isnull().head(5)
dataset[numerical_variable].isnull().head(5)
dataset[categorical_variable].isnull().head(5)

#False - No missing values
#true = we have the missing values
# Out:
#    Gender  Customer Type  Type of Travel  Class  Satisfaction
# 0   False          False           False  False         False
# 1   False          False           False  False         False
# 2   False          False           False  False         False
# 3   False          False           False  False         False
# 4   False          False           False  False         False

# %%
#Find out the the percentage of missing values
len(dataset)
# Out:
# 129880

# %%
dataset.isnull().sum()/len(dataset)
dataset[numerical_variable].isnull().sum()
dataset[numerical_variable].isnull().sum()/len(dataset)
# Out:
# ID                                        0.000000
# Age                                       0.000000
# Flight Distance                           0.000000
# Departure Delay                           0.000000
# Arrival Delay                             0.003026
# Departure and Arrival Time Convenience    0.000000
# Ease of Online Booking                    0.000000
# Check-in Service                          0.000000
# Online Boarding                           0.000000
# Gate Location                             0.000000
# On-board Service                          0.000000
# Seat Comfort                              0.000000
# Leg Room Service                          0.000000
# Cleanliness                               0.000000
# Food and Drink                            0.000000
# In-flight Service                         0.000000
# In-flight Wifi Service                    0.000000
# In-flight Entertainment                   0.000000
# ...

# %%
dataset.fillna('Kirirom')
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay Arrival Delay  \
# 0                   821                2           5.0
# ...

# %%
dataset['Customer Type'].replace('Returning', 'Comeback')
dataset.replace(0, "Kirirom")
dataset['Class'].replace(["Business", "Economy Plus"],['World Class',"Economy Minus"]).head(15)
# Out:
# 0           World Class
# 1           World Class
# 2           World Class
# 3           World Class
# 4           World Class
#               ...
# 129875    Economy Minus
# 129876    Economy Minus
# 129877    Economy Minus
# 129878    Economy Minus
# 129879    Economy Minus
# Name: Class, Length: 129880, dtype: object

# %%
#Create the rows and add it with the original dataset
#values of variable, instructions about the variable
row_insert = pd.Series([len(dataset)+1,'Male','19', 'Returning', "Personal", "Business"  ], index = ['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class'])
dataset.append(row_insert, ignore_index=True)
# Out:
#             ID  Gender Age Customer Type Type of Travel         Class  \
# 0            1    Male  48    First-time       Business      Business
# 1            2  Female  35     Returning       Business      Business
# 2            3    Male  41     Returning       Business      Business
# 3            4    Male  50     Returning       Business      Business
# 4            5  Female  49     Returning       Business      Business
# ...        ...     ...  ..           ...            ...           ...
# 129876  129877    Male  41     Returning       Personal  Economy Plus
# 129877  129878    Male  42     Returning       Personal  Economy Plus
# 129878  129879    Male  50     Returning       Personal  Economy Plus
# 129879  129880  Female  20     Returning       Personal  Economy Plus
# 129880  129881    Male  19     Returning       Personal      Business
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                 821.0              2.0            5.0
# ...

# %%
#call the row
#datasetname.iloc[] - we can call the specific row based on the index
dataset.iloc[0]
dataset.iloc[1:10]
dataset.iloc[1:20]
dataset.iloc[len(dataset)-1]
# Out:
# ID                                                         129880
# Gender                                                     Female
# Age                                                            20
# Customer Type                                           Returning
# Type of Travel                                           Personal
# Class                                                Economy Plus
# Flight Distance                                               337
# Departure Delay                                                 0
# Arrival Delay                                                 0.0
# Departure and Arrival Time Convenience                          1
# Ease of Online Booking                                          3
# Check-in Service                                                4
# Online Boarding                                                 3
# Gate Location                                                   2
# ...

# %%
#loc - to cal the specific values, 
#index
dataset = dataset.set_index(dataset['Class'])
dataset.loc['Economy Plus']
# Out:
#                   ID  Gender  Age Customer Type Type of Travel         Class  \
# Class
# Economy Plus      24    Male   77     Returning       Business  Economy Plus
# Economy Plus      94    Male   80     Returning       Business  Economy Plus
# Economy Plus      95  Female    7     Returning       Personal  Economy Plus
# Economy Plus      96  Female   34     Returning       Personal  Economy Plus
# Economy Plus      97  Female   18    First-time       Business  Economy Plus
# ...              ...     ...  ...           ...            ...           ...
# Economy Plus  129876    Male   28     Returning       Personal  Economy Plus
# Economy Plus  129877    Male   41     Returning       Personal  Economy Plus
# Economy Plus  129878    Male   42     Returning       Personal  Economy Plus
# Economy Plus  129879    Male   50     Returning       Personal  Economy Plus
# Economy Plus  129880  Female   20     Returning       Personal  Economy Plus
#
# ...

# %%
#rename
dataset.rename(columns={'Class' : 'Type'}).head(5)
# Out:
#           ID  Gender  Age Customer Type Type of Travel      Type  \
# Class
# Business   1    Male   48    First-time       Business  Business
# Business   2  Female   35     Returning       Business  Business
# Business   3    Male   41     Returning       Business  Business
# Business   4    Male   50     Returning       Business  Business
# Business   5  Female   49     Returning       Business  Business
#
#           Flight Distance  Departure Delay  Arrival Delay  \
# Class
# Business              821                2            5.0
# Business              821               26           39.0
# Business              853                0            0.0
# Business             1905                0            0.0
# Business             3470                0            1.0
#
#           Departure and Arrival Time Convenience  ...  On-board Service  \
# Class                                             ...
# Business                                       3  ...                 3
# ...

# %%
print('Highest Distance:', dataset['Flight Distance'].max())
# Out:
# Highest Distance: 4983

# %%
#delete col
dataset.drop('Gender', axis=1).head(5)
dataset.drop(dataset.columns[2], axis=1)
# Out:
#                   ID  Gender Customer Type Type of Travel         Class  \
# Class
# Business           1    Male    First-time       Business      Business
# Business           2  Female     Returning       Business      Business
# Business           3    Male     Returning       Business      Business
# Business           4    Male     Returning       Business      Business
# Business           5  Female     Returning       Business      Business
# ...              ...     ...           ...            ...           ...
# Economy Plus  129876    Male     Returning       Personal  Economy Plus
# Economy Plus  129877    Male     Returning       Personal  Economy Plus
# Economy Plus  129878    Male     Returning       Personal  Economy Plus
# Economy Plus  129879    Male     Returning       Personal  Economy Plus
# Economy Plus  129880  Female     Returning       Personal  Economy Plus
#
#               Flight Distance  Departure Delay  Arrival Delay  \
# Class
# ...

# %%
#delete row
dataset.drop(["Business"], axis =0)
# Out:
#                   ID  Gender  Age Customer Type Type of Travel         Class  \
# Class
# Economy           13    Male   24    First-time       Business       Economy
# Economy           15    Male   52     Returning       Personal       Economy
# Economy           16    Male   70     Returning       Personal       Economy
# Economy           17  Female   48     Returning       Personal       Economy
# Economy           18  Female   61     Returning       Personal       Economy
# ...              ...     ...  ...           ...            ...           ...
# Economy Plus  129876    Male   28     Returning       Personal  Economy Plus
# Economy Plus  129877    Male   41     Returning       Personal  Economy Plus
# Economy Plus  129878    Male   42     Returning       Personal  Economy Plus
# Economy Plus  129879    Male   50     Returning       Personal  Economy Plus
# Economy Plus  129880  Female   20     Returning       Personal  Economy Plus
#
# ...

# %%
dataset['Type of Travel'].unique()
# Out:
# array(['Business', 'Personal'], dtype=object)
